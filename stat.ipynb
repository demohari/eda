# %%
import numpy as np
import pandas as pd
from statistics import mean, median ,mode 
from scipy import stats
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 5000)
pd.set_option('display.width', 1000)

# %%
population=np.random.randint(10,20,50)
population
# Out:
# array([14, 14, 10, 18, 19, 13, 18, 11, 16, 14, 12, 16, 18, 13, 18, 19, 14,
#        13, 17, 16, 15, 16, 11, 17, 18, 11, 19, 11, 13, 17, 12, 13, 19, 12,
#        15, 11, 16, 15, 12, 19, 13, 17, 16, 15, 15, 15, 13, 14, 18, 10])

# %%
population.mean()
# Out:
# 14.82

# %%
np.mean(population)
# Out:
# 14.82

# %%
stats.mode(population)
# Out:
# /tmp/ipykernel_2502/2055905347.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(population)
# ModeResult(mode=array([13]), count=array([7]))

# %%
stats.mode(population)[0]
# Out:
# /tmp/ipykernel_2502/1277322309.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(population)[0]
# array([13])

# %%
mode(population)
# Out:
# 13

# %%
print(f"mean of the sample {np.mean(population)}")
print(f"median of the sample {np.median(population)}")
print(f"mode of the sample {mode(population)}")
# Out:
# mean of the sample 14.82
# median of the sample 15.0
# mode of the sample 13

# %%
sample1=np.random.choice(population,20)
sample2=np.random.choice(population,20)
sample3=np.random.choice(population,20)
sample4=np.random.choice(population,20)

# %%
print(f"population:{population}")
print(60*"=")
print(sample1)
print(60*"=")
print(sample2)
print(60*"=")
print(sample3)
print(60*"=")
print(sample4)
# Out:
# population:[14 14 10 18 19 13 18 11 16 14 12 16 18 13 18 19 14 13 17 16 15 16 11 17
#  18 11 19 11 13 17 12 13 19 12 15 11 16 15 12 19 13 17 16 15 15 15 13 14
#  18 10]
# ============================================================
# [16 16 12 19 11 18 13 11 18 11 14 17 11 14 15 14 17 19 11 13]
# ============================================================
# [16 19 11 17 13 19 16 14 16 16 15 16 12 11 18 19 15 14 16 16]
# ============================================================
# [11 15 11 14 16 13 16 13 18 19 13 10 15 13 11 15 18 16 12 17]
# ============================================================
# [10 14 14 13 15 18 16 16 16 16 12 11 18 12 12 15 15 13 12 18]

# %%
print("population")
print(f"mean of the sample {np.mean(population)}")
print(f"median of the sample {np.median(population)}")
print(f"mode of the sample {mode(population)}")
print("sample1")
print(f"mean of the sample {np.mean(sample1)}")
print(f"median of the sample {np.median(sample1)}")
print(f"mode of the sample {mode(sample1)}")
print("sample2")
print(f"mean of the sample {np.mean(sample2)}")
print(f"median of the sample {np.median(sample2)}")
print(f"mode of the sample {mode(sample2)}")
print("sample3")
print(f"mean of the sample {np.mean(sample3)}")
print(f"median of the sample {np.median(sample3)}")
print(f"mode of the sample {mode(sample3)}")
print("sample4")
print(f"mean of the sample {np.mean(sample4)}")
print(f"median of the sample {np.median(sample4)}")
print(f"mode of the sample {mode(sample4)}")
# Out:
# population
# mean of the sample 14.82
# median of the sample 15.0
# mode of the sample 13
# sample1
# mean of the sample 14.5
# median of the sample 14.0
# mode of the sample 11
# sample2
# mean of the sample 15.45
# median of the sample 16.0
# mode of the sample 16
# sample3
# mean of the sample 14.3
# median of the sample 14.5
# mode of the sample 13
# sample4
# mean of the sample 14.3
# median of the sample 14.5
# mode of the sample 16

# %%
mean_of_samples=[]
median_of_samples=[]
mode_of_samples=[]

all_sample=[sample1,sample2,sample3,sample4]

for sample in all_sample:
    mean_of_samples.append(np.mean(sample))
    median_of_samples.append(np.median(sample))
    mode_of_samples.append(mode(sample))

# %%
mean_of_samples, median_of_samples,mode_of_samples
# Out:
# ([14.5, 15.45, 14.3, 14.3], [14.0, 16.0, 14.5, 14.5], [11, 16, 13, 16])

# %%
print(f"mean of the sample {mean_of_samples}")
print(f"median of the sample {median_of_samples}")
print(f"mode of the sample {mode_of_samples}")
# Out:
# mean of the sample [14.5, 15.45, 14.3, 14.3]
# median of the sample [14.0, 16.0, 14.5, 14.5]
# mode of the sample [11, 16, 13, 16]

# %%
population=np.random.binomial(10,0.5,10000) #pms function discrete variable
population
# Out:
# array([5, 6, 5, ..., 6, 5, 5])

# %%
import seaborn as sns
sns.distplot(population)
# Out:
# /tmp/ipykernel_2502/2113714884.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(population)
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
sns.displot(population,kde=True)

# %%
import seaborn as sns
sns.histplot(population,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
size=int(len(population)*0.30)

# %%
np.mean(population)
# Out:
# 4.996

# %%
sample_mean=[]
for i in range(1,31):
    sample=np.random.choice(population,size=size)
    print(sample)
    sample_mean.append(np.mean(sample))

sample_mean
# Out:
# [5 8 2 ... 7 6 6]
# [4 6 5 ... 6 4 4]
# [4 3 7 ... 5 6 5]
# [6 5 4 ... 5 5 5]
# [4 5 6 ... 4 7 5]
# [6 3 3 ... 3 3 5]
# [5 4 5 ... 6 5 5]
# [5 5 5 ... 5 4 2]
# [4 4 5 ... 3 4 4]
# [3 3 8 ... 5 6 5]
# [5 3 6 ... 6 6 5]
# [2 3 7 ... 4 6 6]
# [6 5 5 ... 5 7 4]
# [5 3 5 ... 5 3 5]
# [5 5 5 ... 6 3 4]
# [3 5 2 ... 5 6 5]
# [5 6 7 ... 4 5 3]
# [5 6 4 ... 4 6 3]
# [2 5 6 ... 4 5 6]
# [6 4 3 ... 3 5 6]
# [4 7 6 ... 5 4 7]
# [5 4 4 ... 7 4 4]
# [5 6 5 ... 6 2 5]
# [6 5 8 ... 3 2 8]
# [5 5 4 ... 5 8 5]
# [3 4 2 ... 7 7 4]
# [1 8 5 ... 5 6 5]
# [4 5 7 ... 5 4 4]
# [6 4 4 ... 4 5 3]
# [5 6 8 ... 4 4 2]
# [4.960666666666667,
#  4.993,
#  4.968666666666667,
#  5.012666666666667,
#  5.04,
#  5.02,
#  4.9446666666666665,
#  4.994666666666666,
#  5.011333333333333,
#  5.017,
#  4.979333333333333,
#  4.975,
#  5.043333333333333,
#  4.974333333333333,
#  5.012,
#  5.034666666666666,
#  5.054333333333333,
#  4.9976666666666665,
#  5.029333333333334,
#  4.963666666666667,
#  4.989333333333334,
#  5.009333333333333,
#  5.014666666666667,
#  4.973333333333334,
#  5.019666666666667,
#  4.957333333333334,
#  4.998333333333333,
#  4.995,
#  4.974333333333333,
#  4.9656666666666665]

# %%
sns.distplot(sample_mean)
# Out:
# /tmp/ipykernel_2502/514007480.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_mean)
# <Axes: ylabel='Density'>

# %%
sns.displot(sample_mean,kde=True)

# %%
sns.histplot(sample_mean,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
#different sampling methods
""" random sampling
stratified
cluster
systematic """
