# %%
import numpy as np
import pandas as pd
from statistics import mean, median ,mode 
from scipy import stats
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 5000)
pd.set_option('display.width', 1000)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
population=np.random.randint(10,20,50)
population
# Out:
# array([18, 15, 12, 12, 18, 13, 19, 10, 11, 10, 19, 13, 11, 14, 11, 11, 18,
#        14, 11, 18, 12, 13, 17, 19, 19, 18, 12, 17, 18, 17, 12, 10, 14, 14,
#        13, 17, 19, 13, 10, 15, 19, 19, 17, 10, 14, 14, 12, 10, 19, 14])

# %%
population.mean()
# Out:
# 14.5

# %%
np.mean(population)
# Out:
# 14.5

# %%
stats.mode(population)
# Out:
# /tmp/ipykernel_948/2055905347.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(population)
# ModeResult(mode=array([19]), count=array([8]))

# %%
stats.mode(population)[0]
# Out:
# /tmp/ipykernel_948/1277322309.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(population)[0]
# array([19])

# %%
mode(population)
# Out:
# 19

# %%
print(f"mean of the sample {np.mean(population)}")
print(f"median of the sample {np.median(population)}")
print(f"mode of the sample {mode(population)}")
# Out:
# mean of the sample 14.5
# median of the sample 14.0
# mode of the sample 19

# %%
sample1=np.random.choice(population,20)
sample2=np.random.choice(population,20)
sample3=np.random.choice(population,20)
sample4=np.random.choice(population,20)

# %%
print(f"population:{population}")
print(60*"=")
print(sample1)
print(60*"=")
print(sample2)
print(60*"=")
print(sample3)
print(60*"=")
print(sample4)
# Out:
# population:[18 15 12 12 18 13 19 10 11 10 19 13 11 14 11 11 18 14 11 18 12 13 17 19
#  19 18 12 17 18 17 12 10 14 14 13 17 19 13 10 15 19 19 17 10 14 14 12 10
#  19 14]
# ...
# [19 19 12 18 11 19 19 15 11 17 19 17 18 17 10 14 10 12 14 12]
# ...
# [10 17 18 18 11 12 15 14 15 14 14 17 10 19 10 19 13 13 10 10]
# ...
# [19 11 12 14 11 17 19 19 11 10 19 11 17 11 12 19 19 14 10 13]
# ...
# [12 13 14 12 13 10 10 17 12 19 14 18 12 18 14 13 12 14 11 13]

# %%
print("population")
print(f"mean of the sample {np.mean(population)}")
print(f"median of the sample {np.median(population)}")
print(f"mode of the sample {mode(population)}")
print("sample1")
print(f"mean of the sample {np.mean(sample1)}")
print(f"median of the sample {np.median(sample1)}")
print(f"mode of the sample {mode(sample1)}")
print("sample2")
print(f"mean of the sample {np.mean(sample2)}")
print(f"median of the sample {np.median(sample2)}")
print(f"mode of the sample {mode(sample2)}")
print("sample3")
print(f"mean of the sample {np.mean(sample3)}")
print(f"median of the sample {np.median(sample3)}")
print(f"mode of the sample {mode(sample3)}")
print("sample4")
print(f"mean of the sample {np.mean(sample4)}")
print(f"median of the sample {np.median(sample4)}")
print(f"mode of the sample {mode(sample4)}")
# Out:
# population
# mean of the sample 14.5
# median of the sample 14.0
# mode of the sample 19
# sample1
# mean of the sample 15.15
# median of the sample 16.0
# mode of the sample 19
# sample2
# mean of the sample 13.95
# median of the sample 14.0
# mode of the sample 10
# sample3
# mean of the sample 14.4
# median of the sample 13.5
# mode of the sample 19
# sample4
# mean of the sample 13.55
# median of the sample 13.0
# mode of the sample 12

# %%
mean_of_samples=[]
median_of_samples=[]
mode_of_samples=[]

all_sample=[sample1,sample2,sample3,sample4]

for sample in all_sample:
    mean_of_samples.append(np.mean(sample))
    median_of_samples.append(np.median(sample))
    mode_of_samples.append(mode(sample))

# %%
mean_of_samples, median_of_samples,mode_of_samples
# Out:
# ([15.15, 13.95, 14.4, 13.55], [16.0, 14.0, 13.5, 13.0], [19, 10, 19, 12])

# %%
print(f"mean of the sample {mean_of_samples}")
print(f"median of the sample {median_of_samples}")
print(f"mode of the sample {mode_of_samples}")
# Out:
# mean of the sample [15.15, 13.95, 14.4, 13.55]
# median of the sample [16.0, 14.0, 13.5, 13.0]
# mode of the sample [19, 10, 19, 12]

# %%
population=np.random.binomial(10,0.5,10000) #pms function discrete variable
population
# Out:
# array([6, 5, 5, ..., 5, 7, 4])

# %%
import seaborn as sns
sns.distplot(population)
# Out:
# /tmp/ipykernel_948/2113714884.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(population)
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
sns.displot(population,kde=True)

# %%
import seaborn as sns
sns.histplot(population,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
size=int(len(population)*0.30)

# %%
np.mean(population)
# Out:
# 4.981

# %%
sample_mean=[]
for i in range(1,31):
    sample=np.random.choice(population,size=size)
    print(sample)
    sample_mean.append(np.mean(sample))

sample_mean
# Out:
# [6 5 6 ... 6 2 4]
# [7 8 3 ... 7 4 2]
# [5 8 6 ... 5 6 5]
# [5 4 3 ... 6 4 3]
# [5 4 3 ... 5 4 4]
# [5 6 6 ... 6 5 4]
# [8 7 4 ... 5 6 3]
# [6 4 5 ... 5 4 5]
# [3 7 6 ... 7 6 7]
# [3 7 5 ... 6 5 7]
# [6 7 7 ... 2 4 4]
# [9 5 8 ... 4 4 6]
# [7 8 6 ... 2 5 6]
# [5 4 4 ... 4 7 5]
# [5 5 7 ... 4 4 7]
# [8 2 3 ... 4 4 7]
# [4 7 6 ... 5 3 5]
# [7 3 3 ... 6 7 4]
# [6 4 6 ... 5 6 6]
# [4 4 4 ... 5 7 3]
# [5 6 4 ... 4 4 5]
# [3 1 3 ... 7 6 4]
# [5 6 4 ... 6 5 5]
# [5 4 5 ... 6 5 4]
# [5 8 5 ... 9 3 6]
# [6 3 6 ... 4 5 3]
# [6 3 8 ... 5 8 3]
# [3 6 5 ... 2 3 3]
# [5 4 2 ... 3 4 5]
# [6 4 6 ... 5 6 1]
# [4.975666666666666,
#  5.050666666666666,
#  4.992666666666667,
#  4.950666666666667,
#  4.991333333333333,
#  4.966333333333333,
#  4.947333333333333,
#  4.960666666666667,
#  4.941,
#  5.001,
#  5.003,
#  5.0456666666666665,
#  4.969666666666667,
#  4.996,
#  4.941,
#  4.966333333333333,
#  4.984,
#  4.946666666666666,
#  5.05,
#  4.961666666666667,
#  4.974333333333333,
#  4.994666666666666,
# ...

# %%
sns.distplot(sample_mean)
# Out:
# /tmp/ipykernel_948/514007480.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_mean)
# <Axes: ylabel='Density'>

# %%
sns.displot(sample_mean,kde=True)

# %%
sns.histplot(sample_mean,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
#different sampling methods
""" random sampling
stratified
cluster
systematic """
# Out:
# ' random sampling\nstratified\ncluster\nsystematic '

# %%
#import the dataset
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-red.csv",sep=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0            7.4              0.70         0.00             1.9      0.076                 11.0                  34.0   0.9978  3.51       0.56      9.4        5
# 1            7.8              0.88         0.00             2.6      0.098                 25.0                  67.0   0.9968  3.20       0.68      9.8        5
# 2            7.8              0.76         0.04             2.3      0.092                 15.0                  54.0   0.9970  3.26       0.65      9.8        5
# 3           11.2              0.28         0.56             1.9      0.075                 17.0                  60.0   0.9980  3.16       0.58      9.8        6
# 4            7.4              0.70         0.00             1.9      0.076                 11.0                  34.0   0.9978  3.51       0.56      9.4        5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide      density           pH    sulphates      alcohol      quality
# count    1599.000000       1599.000000  1599.000000     1599.000000  1599.000000          1599.000000           1599.000000  1599.000000  1599.000000  1599.000000  1599.000000  1599.000000
# mean        8.319637          0.527821     0.270976        2.538806     0.087467            15.874922             46.467792     0.996747     3.311113     0.658149    10.422983     5.636023
# std         1.741096          0.179060     0.194801        1.409928     0.047065            10.460157             32.895324     0.001887     0.154386     0.169507     1.065668     0.807569
# min         4.600000          0.120000     0.000000        0.900000     0.012000             1.000000              6.000000     0.990070     2.740000     0.330000     8.400000     3.000000
# ...

# %%
df['volatile acidity']
# Out:
# 0       0.700
# 1       0.880
# 2       0.760
# 3       0.280
# 4       0.700
#         ...
# 1594    0.600
# 1595    0.550
# 1596    0.510
# 1597    0.645
# 1598    0.310
# Name: volatile acidity, Length: 1599, dtype: float64

# %%
sns.distplot(df['volatile acidity'])
# Out:
# <Axes: xlabel='volatile acidity', ylabel='Density'>

# %%
sns.distplot(df['volatile acidity'],kde=True)
# Out:
# <Axes: xlabel='volatile acidity', ylabel='Density'>

# %%
sns.distplot(df['volatile acidity'],kde=True,color='red')
# Out:
# <Axes: xlabel='volatile acidity', ylabel='Density'>

# %%
fig, axes = plt.subplots(ncols=len(df.columns), figsize=(30,15))
for ax, col in zip(axes, df.columns):
    #print(col)
    sns.distplot(df[col], ax=ax)
    plt.tight_layout() 
plt.show()

# %%
len
# Out:
# 12

# %%
#to test weather data is normally distributed
#shapiro-test
#normaltest

# %%
from scipy import stats

# %%
stats.shapiro(df)
# Out:
# ShapiroResult(statistic=0.4830079674720764, pvalue=0.0)

# %%
for col in df.columns:
    #print(f"{col}:{stats.shapiro(df[col])}")
    if stats.shapiro(df[col])[1]>=0.05:
        print(f"{col}: distribution is NORMAL ++")
    else:
        print(f"{col}: distribution is NOT NORMAL --")
# Out:
# fixed acidity: distribution is NOT NORMAL --
# volatile acidity: distribution is NOT NORMAL --
# citric acid: distribution is NOT NORMAL --
# residual sugar: distribution is NOT NORMAL --
# chlorides: distribution is NOT NORMAL --
# free sulfur dioxide: distribution is NOT NORMAL --
# total sulfur dioxide: distribution is NOT NORMAL --
# density: distribution is NOT NORMAL --
# pH: distribution is NOT NORMAL --
# sulphates: distribution is NOT NORMAL --
# alcohol: distribution is NOT NORMAL --
# quality: distribution is NOT NORMAL --

# %%
for col in df.columns:
    print(f"{col}:{stats.shapiro(df[col])}")
    if stats.shapiro(df[col])[1]>=0.05:
        print(f"{col}: distribution is NORMAL ++")
    else:
        print(f"{col}: distribution is NOT NORMAL --")
# Out:
# fixed acidity:ShapiroResult(statistic=0.9420264959335327, pvalue=1.5227779442162196e-24)
# fixed acidity: distribution is NOT NORMAL --
# volatile acidity:ShapiroResult(statistic=0.9743338823318481, pvalue=2.686385373947307e-16)
# volatile acidity: distribution is NOT NORMAL --
# citric acid:ShapiroResult(statistic=0.955294668674469, pvalue=1.0233944777578548e-21)
# citric acid: distribution is NOT NORMAL --
# residual sugar:ShapiroResult(statistic=0.5660766363143921, pvalue=0.0)
# residual sugar: distribution is NOT NORMAL --
# chlorides:ShapiroResult(statistic=0.4842468500137329, pvalue=0.0)
# chlorides: distribution is NOT NORMAL --
# free sulfur dioxide:ShapiroResult(statistic=0.9018418192863464, pvalue=7.699692533903026e-31)
# free sulfur dioxide: distribution is NOT NORMAL --
# total sulfur dioxide:ShapiroResult(statistic=0.8732250332832336, pvalue=3.573768919849872e-34)
# total sulfur dioxide: distribution is NOT NORMAL --
# ...

# %%
from numpy.random import randn
mydata=randn(500)

# %%
sns.distplot(mydata)
# Out:
# <Axes: ylabel='Density'>

# %%
result=stats.shapiro(mydata)

# %%
if result[1] >=0.05:
    print("NORMAL")
else:
    print("NOT_NORMAL")
# Out:
# NORMAL

# %%
from numpy.random import randn
mydata=randn(500)

# %%
sns.distplot(mydata)
# Out:
# <Axes: ylabel='Density'>

# %%
result=stats.shapiro(mydata)

# %%
if result[1] >=0.05:
    print("NORMAL")
else:
    print("NOT_NORMAL")
# Out:
# NORMAL

# %%
from scipy import stats
result=stats.normaltest(df['citric acid'])
result
# Out:
# NormaltestResult(statistic=152.039214793795, pvalue=9.662822259281018e-34)

# %%
if result[1] >=0.05:
    print("NORMAL")
else:
    print("NOT_NORMAL")
# Out:
# NOT_NORMAL

# %%
stats.normaltest(df['citric acid'])
# Out:
# NormaltestResult(statistic=152.039214793795, pvalue=9.662822259281018e-34)

# %%
for col in df.columns:
    print(f"{col}:{stats.normaltest(df[col])}")
    if stats.normaltest(df[col])[1]>=0.05:
        print(f"{col}: distribution is NORMAL ++")
    else:
        print(f"{col}: distribution is NOT NORMAL --")
# Out:
# fixed acidity:NormaltestResult(statistic=224.53087840457746, pvalue=1.7528277735470436e-49)
# fixed acidity: distribution is NOT NORMAL --
# volatile acidity:NormaltestResult(statistic=143.4193435598286, pvalue=7.192589039756692e-32)
# volatile acidity: distribution is NOT NORMAL --
# citric acid:NormaltestResult(statistic=152.039214793795, pvalue=9.662822259281018e-34)
# citric acid: distribution is NOT NORMAL --
# residual sugar:NormaltestResult(statistic=1520.3239698236891, pvalue=0.0)
# residual sugar: distribution is NOT NORMAL --
# chlorides:NormaltestResult(statistic=1783.1059225626427, pvalue=0.0)
# chlorides: distribution is NOT NORMAL --
# free sulfur dioxide:NormaltestResult(statistic=342.2591484251238, pvalue=4.779365332171477e-75)
# free sulfur dioxide: distribution is NOT NORMAL --
# total sulfur dioxide:NormaltestResult(statistic=487.42725648953467, pvalue=1.433890834343538e-106)
# total sulfur dioxide: distribution is NOT NORMAL --
# ...

# %%
for col in df.columns:
    print(f"{col}:{stats.shapiro(df[col])}")
    if stats.shapiro(df[col])[1]>=0.05:
        print(f"{col}: distribution is NORMAL ++")
    else:
        print(f"{col}: distribution is NOT NORMAL --")
# Out:
# fixed acidity:ShapiroResult(statistic=0.9420264959335327, pvalue=1.5227779442162196e-24)
# fixed acidity: distribution is NOT NORMAL --
# volatile acidity:ShapiroResult(statistic=0.9743338823318481, pvalue=2.686385373947307e-16)
# volatile acidity: distribution is NOT NORMAL --
# citric acid:ShapiroResult(statistic=0.955294668674469, pvalue=1.0233944777578548e-21)
# citric acid: distribution is NOT NORMAL --
# residual sugar:ShapiroResult(statistic=0.5660766363143921, pvalue=0.0)
# residual sugar: distribution is NOT NORMAL --
# chlorides:ShapiroResult(statistic=0.4842468500137329, pvalue=0.0)
# chlorides: distribution is NOT NORMAL --
# free sulfur dioxide:ShapiroResult(statistic=0.9018418192863464, pvalue=7.699692533903026e-31)
# free sulfur dioxide: distribution is NOT NORMAL --
# total sulfur dioxide:ShapiroResult(statistic=0.8732250332832336, pvalue=3.573768919849872e-34)
# total sulfur dioxide: distribution is NOT NORMAL --
# ...

# %%
sample_mean_iq=110
alpha=0.05
#ci=95%
std_dev=15
mean_population=100
sample=50
null_hyphothesis_value=100

# %%
data=mean_std_dev*randn(50)+mean_population

# %%
np.mean(data)
# Out:
# 99.91876212250757

# %%
from statsmodels.stats.weightstats import ztest
result =ztest(data,value=null_hyphothesis_value,alternative='larger')
result
# Out:
# (-0.03719804438741303, 0.5148364510562081)

# %%
result[1]
# Out:
# 0.5148364510562081

# %%
if result[1] >=0.05:
    print("NORMAL")
else:
    print("NOT_NORMAL")
# Out:
# NORMAL

# %%
import random
import numpy as np
pop=np.random.randint(10,50,50)
pop
# Out:
# array([34, 14, 30, 29, 12, 32, 22, 29, 31, 26, 44, 22, 12, 17, 38, 18, 11,
#        24, 28, 15, 21, 31, 37, 42, 45, 19, 40, 11, 41, 49, 23, 18, 22, 17,
#        39, 11, 21, 16, 39, 34, 23, 22, 43, 32, 30, 15, 19, 38, 15, 22])

# %%
population=np.random.randint(10,50,50)

# %%
sample1=np.random.choice(population,20)
print(sample1.mean())
sample2=np.random.choice(population,20)
print(sample2.mean())
# Out:
# 31.15
# 29.4

# %%
my_cricket_score=[22, 38, 19, 15, 48, 11, 10, 49, 47, 38, 10, 25, 46, 10, 21, 24, 29,36, 25, 24]
np.mean(my_cricket_score)
# Out:
# 27.35

# %%
len(my_cricket_score)
# Out:
# 20

# %%
null_hyphothesis=sample mean should be 27.35

# %%
virat_cricket_score=[33, 45, 23, 25, 46, 46, 46, 49, 49, 14, 14, 44, 25, 31, 25, 40, 30,20, 42, 37]

# %%
np.mean(my_cricket_score)
# Out:
# 34.2

# %%
len(virat_cricket_score)
# Out:
# 20

# %%
null_hyphothesis=sample mean should be 34.2

# %%
import scipy
result=scipy.stats.ttest_1samp(my_cricket_score,15)
result
# Out:
# TtestResult(statistic=4.111530461713795, pvalue=0.0005939030580482863, df=19)

# %%
result[1]
# Out:
# 0.0005939030580482863

# %%
result=scipy.stats.ttest_1samp(virat_cricket_score,15)
result
# Out:
# TtestResult(statistic=7.344129562217983, pvalue=5.828428464397048e-07, df=19)

# %%
result[1]
# Out:
# 5.828428464397048e-07

# %%
scipy.stats.ttest_1samp(my_cricket_score,27)[1]
# Out:
# 0.9084623785416333

# %%
#two-sample t test(with respect to two independent sample)
my_cricket_score=[22, 38, 19, 15, 48, 11, 10, 49, 47, 38, 10, 25, 46, 10, 21, 24, 29,36, 25, 24]

virat_cricket_score=[33, 45, 23, 25, 46, 46, 46, 49, 49, 44, 44, 49, 25, 31, 25, 40, 30,20, 42, 37]

# %%
np.mean(my_cricket_score),np.mean(virat_cricket_score)
# Out:
# (27.35, 34.2)

# %%
#my_null_hyphothsis=both sample mean will be same

# %%
scipy.stats.ttest_ind(my_cricket_score,virat_cricket_score)
# Out:
# Ttest_indResult(statistic=-1.7201915702310573, pvalue=0.09353304669442238)

# %%
result= scipy.stats.ttest_ind(my_cricket_score,virat_cricket_score)
result
# Out:
# Ttest_indResult(statistic=-1.7201915702310573, pvalue=0.09353304669442238)

# %%
if result[1] >=0.05:
    print("NORMAL")
else:
    print("NOT_NORMAL")
# Out:
# NORMAL

# %%
#paired t-test(two sample from the sample population on different time interval)
my_cricket_score_from_first_inning=[22, 38, 19, 15, 48, 11, 10, 49, 47, 38, 10, 25, 46, 10, 21, 24, 29,36, 25, 24]
my_cricket_score_from_second_inning=[22, 38, 29, 15, 18, 11, 10, 49, 47, 38, 50, 45, 46, 40, 21, 24, 29,16, 25, 24]

# %%
print(np.mean(my_cricket_score_from_first_inning))
print(np.mean(my_cricket_score_from_second_inning))
# Out:
# 27.35
# 29.85

# %%
result = scipy.stats.ttest_rel(my_cricket_score_from_first_inning,my_cricket_score_from_second_inning)
result
# Out:
# TtestResult(statistic=-0.7542295906745516, pvalue=0.45995773816634733, df=19)

# %%
if result[1] >=0.05:
    print("NORMAL")
else:
    print("NOT_NORMAL")
# Out:
# NORMAL

# %%
import seaborn as sns
dataset=sns.load_dataset('tips')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
dataset[['sex','smoker']].head()
# Out:
#       sex smoker
# 0  Female     No
# 1    Male     No
# 2    Male     No
# 3    Male     No
# 4  Female     No

# %%
dataset_table=pd.crosstab(dataset['sex'],dataset['smoker'])

# %%
dataset_table
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54
