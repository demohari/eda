# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("/config/workspace/clead_google_playstore_data.csv")
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     9476 non-null   object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.sample(5)
# Out:
#                                    App            Category  Rating  Reviews  \
# 8403                    Galaxy Defense              FAMILY     4.1    78142
# 608     Chat Kids - Chat Room For Kids              DATING     4.7        6
# 9337          EG | Explore Folegandros    TRAVEL_AND_LOCAL     NaN        0
# 1402    Calorie Counter & Diet Tracker  HEALTH_AND_FITNESS     4.5    32606
# 7233  Führerschein Klasse CE, LKW 2018              FAMILY     NaN       57
#
#          Size  Installs  Type  Price Content Rating            Genres  \
# 8403  17000.0   5000000  Free   0.00       Everyone          Strategy
# 608    4900.0       100  Free   0.00     Mature 17+            Dating
# 9337  56000.0         0  Paid   3.99       Everyone    Travel & Local
# 1402      NaN   1000000  Free   0.00       Everyone  Health & Fitness
# 7233      NaN      1000  Paid   2.49       Everyone         Education
#
#      Last Updated         Current Ver Android Ver  day  month  year
# ...

# %%
df.sample()
# Out:
#                                             App Category  Rating  Reviews  \
# 2325  Ovia Parenting & Baby Development Tracker  MEDICAL     4.7     6185
#
#          Size  Installs  Type  Price Content Rating   Genres Last Updated  \
# 2325  38000.0    100000  Free    0.0       Everyone  Medical   2018-08-03
#
#      Current Ver Android Ver  day  month  year
# 2325       1.2.0        4.3     3      8  2018

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.describe()
# Out:
#             Rating       Reviews           Size      Installs         Price  \
# count  9366.000000  1.084000e+04    9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05   21506.534062  1.546434e+07      1.027368
# std       0.515219  2.927761e+06   22596.020795  8.502936e+07     15.949703
# min       1.000000  0.000000e+00      10.000000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01    4900.000000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   13000.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04   30000.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09    400.000000
#
#                 day         month          year
# count  10840.000000  10840.000000  10840.000000
# mean      15.609041      6.422325   2017.399723
# std        9.561621      2.578388      1.100914
# min        1.000000      1.000000   2010.000000
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(df.columns)
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver',
#  'day',
#  'month',
#  'year']

# %%
df_corr=df.corr()
df_corr
# Out:
#             Rating   Reviews      Size  Installs     Price       day  \
# Rating    1.000000  0.068141  0.083950  0.051355 -0.021903 -0.012508
# Reviews   0.068141  1.000000  0.238201  0.643122 -0.009667 -0.030141
# Size      0.083950  0.238201  1.000000  0.164798 -0.022968 -0.009509
# Installs  0.051355  0.643122  0.164798  1.000000 -0.011689 -0.053122
# Price    -0.021903 -0.009667 -0.022968 -0.011689  1.000000 -0.008225
# day      -0.012508 -0.030141 -0.009509 -0.053122 -0.008225  1.000000
# month     0.017254  0.045930  0.039429  0.056447  0.006943 -0.079856
# year      0.137714  0.075537  0.215398  0.089368 -0.007897 -0.016433
#
#              month      year
# Rating    0.017254  0.137714
# Reviews   0.045930  0.075537
# Size      0.039429  0.215398
# Installs  0.056447  0.089368
# Price     0.006943 -0.007897
# day      -0.079856 -0.016433
# month     1.000000 -0.187306
# year     -0.187306  1.000000

# %%
# plotting correlation heatmap
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# displaying heatmap
plt.show()

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10835    False
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# Length: 10840, dtype: bool

# %%
print(f"no of duplicate rows:{len(df[df.duplicated()])}")
df[df.duplicated()]
# Out:
# no of duplicate rows:483
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df[df.duplicated('App')]
# Out:
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10714                  FarmersOnly Dating         DATING     3.0     1145
# 10719  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10729                         FP Notebook        MEDICAL     4.5      410
# 10752      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10767                                AAFP        MEDICAL     3.8       63
#
#           Size  Installs  Type  Price Content Rating         Genres  \
# ...

# %%
df[df.duplicated('Reviews')]
# Out:
#                                           App             Category  Rating  \
# 4       Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN     4.3
# 57                 Extreme Rally Championship    AUTO_AND_VEHICLES     4.2
# 126              Skin Care and Natural Beauty               BEAUTY     NaN
# 134             Lady adviser (beauty, health)               BEAUTY     NaN
# 156    Offline: English to Tagalog Dictionary  BOOKS_AND_REFERENCE     4.7
# ...                                       ...                  ...     ...
# 10834                                FR Forms             BUSINESS     NaN
# 10835                        Sya9a Maroc - FR               FAMILY     4.5
# 10836        Fr. Mike Schmitz Audio Teachings               FAMILY     5.0
# 10837                  Parkinson Exercices FR              MEDICAL     NaN
# 10838           The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
for col in df.columns:
    print(f"{col} :{len(df[df.duplicated(col)])}")
# Out:
# App :1181
# Category :10807
# Rating :10800
# Reviews :4839
# Size :10380
# Installs :10820
# Type :10837
# Price :10748
# Content Rating :10834
# Genres :10721
# Last Updated :9463
# Current Ver :8008
# Android Ver :10807
# day :10809
# month :10828
# year :10831

# %%
df=df.drop_duplicates(subset=['App'],keep='first')

# %%
len(df)
# Out:
# 9659

# %%
print(f"no of duplicate rows:{len(df[df.duplicated()])}")
df[df.duplicated()]
# Out:
# no of duplicate rows:0
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, day, month, year]
# Index: []

# %%
for col in df.columns:
    print(f"{col} :{len(df[df.duplicated(col)])}")
# Out:
# App :0
# Category :9626
# Rating :9619
# Reviews :4329
# Size :9199
# Installs :9639
# Type :9656
# Price :9567
# Content Rating :9653
# Genres :9541
# Last Updated :8282
# Current Ver :6841
# Android Ver :9626
# day :9628
# month :9647
# year :9650

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  day             9659 non-null   int64
#  14  month           9659 non-null   int64
#  15  year            9659 non-null   int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
print(len(numeric_features))
numeric_features
# Out:
# 8
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']
print(len(categorical_features))
categorical_features
# Out:
# 8
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df[numeric_features]
# Out:
#        Rating  Reviews     Size  Installs  Price  day  month  year
# 0         4.1      159  19000.0     10000    0.0    7      1  2018
# 1         3.9      967  14000.0    500000    0.0   15      1  2018
# 2         4.7    87510   8700.0   5000000    0.0    1      8  2018
# 3         4.5   215644  25000.0  50000000    0.0    8      6  2018
# 4         4.3      967   2800.0    100000    0.0   20      6  2018
# ...       ...      ...      ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53000.0      5000    0.0   25      7  2017
# 10836     5.0        4   3600.0       100    0.0    6      7  2018
# 10837     NaN        3   9500.0      1000    0.0   20      1  2017
# 10838     4.5      114      NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19000.0  10000000    0.0   25      7  2018
#
# [9659 rows x 8 columns]

# %%
df[categorical_features]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
len(df['Type'])
# Out:
# 9659

# %%
8902+756
# Out:
# 9658

# %%
df['Type'].isna().sum()
# Out:
# 1

# %%
df['Type'].value_counts()
# Out:
# Free    8902
# Paid     756
# Name: Type, dtype: int64

# %%
df['Type'].value_counts(normalize=True)
#len(df['Type'].value_counts(normalize=True))
# Out:
# Free    0.921723
# Paid    0.078277
# Name: Type, dtype: float64

# %%
df['Type'].value_counts(normalize=True)*100
# Out:
# Free    92.172292
# Paid     7.827708
# Name: Type, dtype: float64

# %%
pd.options.display.max_rows = 2500

# %%
for col in categorical_features:
    
    print(f"Total no of catagories in {col}:{len(df[col].value_counts(normalize=True))}")
# Out:
# Total no of catagories in App:9659
# Total no of catagories in Category:33
# Total no of catagories in Type:2
# Total no of catagories in Content Rating:6
# Total no of catagories in Genres:118
# Total no of catagories in Last Updated:1377
# Total no of catagories in Current Ver:2817
# Total no of catagories in Android Ver:32

# %%
for col in categorical_features:
    print('+'*50)
    print(f"Total no of catagories in {col}:{len(df[col].value_counts(normalize=True))}")
    print('+'*50)
    print(f"{col}:{df[col].value_counts(normalize=True)*100}")
    print("=============================================")
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Total no of catagories in App:9659
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# App:Photo Editor & Candy Camera & Grid & ScrapBook    0.010353
# Tic Tac CK                                        0.010353
# INFAMY RO                                         0.010353
# CK Call NEW                                       0.010353
# Ck Coif                                           0.010353
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010353
# Dance School Stories - Dance Dreams Come True     0.010353
# 3D Bowling                                        0.010353
# Mind Games Pro                                    0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010353
# Name: App, Length: 9659, dtype: float64
# ...
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# Total no of catagories in Category:33
# ...

# %%
sns.countplot(x=df["Type"])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
""" # categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = categorical_features
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()  """
# Out:
# ' # categorical columns\nplt.figure(figsize=(20, 15))\nplt.suptitle(\'Univariate Analysis of Categorical Features\', fontsize=20, fontweight=\'bold\', alpha=0.8, y=1.)\ncategory = categorical_features\nfor i in range(0, len(category)):\n    plt.subplot(2, 2, i+1)\n    sns.countplot(x=df[category[i]],palette="Set2")\n    plt.xlabel(category[i])\n    plt.xticks(rotation=45)\n    plt.tight_layout()  '

# %%
""" 
for feature in categorical_features:
  sns.countplot(data=df, x=feature, palette='deep')
  plt.xticks(rotation=65)
  plt.show() """
# Out:
# " \nfor feature in categorical_features:\n  sns.countplot(data=df, x=feature, palette='deep')\n  plt.xticks(rotation=65)\n  plt.show() "

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df['Reviews'])
# Out:
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
sns.kdeplot(df['Reviews'])
# Out:
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
sns.kdeplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.histplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
plt.hist(df["Rating"])
plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True, color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
df['App'].value_counts().plot()
# Out:
# <Axes: >

# %%
""" df["App"].value_counts().plot.pie(y=df["App"],figsize=(15,15),autopct='%1.1f%%') """
# Out:
# ' df["App"].value_counts().plot.pie(y=df["App"],figsize=(15,15),autopct=\'%1.1f%%\') '

# %%
df["Category"].value_counts().plot.pie(y=df["Category"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Category'>

# %%
df_cat=df["Category"].value_counts()
df_cat
# Out:
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           64
# PARENTING                60
# COMICS                   56
# BEAUTY                   53
# ...

# %%
df_cat=df["Category"].value_counts()[:10]
df_cat
# Out:
# FAMILY             1832
# GAME                959
# TOOLS               827
# BUSINESS            420
# MEDICAL             395
# PERSONALIZATION     376
# PRODUCTIVITY        374
# LIFESTYLE           369
# FINANCE             345
# SPORTS              325
# Name: Category, dtype: int64

# %%
category = pd.DataFrame(df['Category'].value_counts())        #Dataframe of apps on the basis of category
#category.rename(columns = {'Category':'Count'},inplace=True)
category
# Out:
#                      Category
# FAMILY                   1832
# GAME                      959
# TOOLS                     827
# BUSINESS                  420
# MEDICAL                   395
# PERSONALIZATION           376
# PRODUCTIVITY              374
# LIFESTYLE                 369
# FINANCE                   345
# SPORTS                    325
# COMMUNICATION             315
# HEALTH_AND_FITNESS        288
# PHOTOGRAPHY               281
# NEWS_AND_MAGAZINES        254
# SOCIAL                    239
# BOOKS_AND_REFERENCE       222
# TRAVEL_AND_LOCAL          219
# SHOPPING                  202
# DATING                    171
# VIDEO_PLAYERS             163
# MAPS_AND_NAVIGATION       131
# EDUCATION                 119
# FOOD_AND_DRINK            112
# ENTERTAINMENT             102
# AUTO_AND_VEHICLES          85
# LIBRARIES_AND_DEMO         84
# WEATHER                    79
# HOUSE_AND_HOME             74
# EVENTS                     64
# ART_AND_DESIGN             64
# ...

# %%
category = pd.DataFrame(df['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)
category[:10]
# Out:
#                  Count
# FAMILY            1832
# GAME               959
# TOOLS              827
# BUSINESS           420
# MEDICAL            395
# PERSONALIZATION    376
# PRODUCTIVITY       374
# LIFESTYLE          369
# FINANCE            345
# SPORTS             325

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df_cat, y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby(['Category'])['Installs'].sum()
# Out:
# Category
# ART_AND_DESIGN           114338100
# AUTO_AND_VEHICLES         53130211
# BEAUTY                    27197050
# BOOKS_AND_REFERENCE     1665969576
# BUSINESS                 697164865
# COMICS                    44981150
# COMMUNICATION          11038276251
# DATING                   140926107
# EDUCATION                352952000
# ENTERTAINMENT           2113660000
# EVENTS                    15973161
# FAMILY                  4427941505
# FINANCE                  455348734
# FOOD_AND_DRINK           211798751
# GAME                   13878924415
# HEALTH_AND_FITNESS      1144022512
# HOUSE_AND_HOME            97212461
# LIBRARIES_AND_DEMO        52995910
# LIFESTYLE                503823539
# MAPS_AND_NAVIGATION      503281890
# MEDICAL                   38193177
# NEWS_AND_MAGAZINES      2369217760
# PARENTING                 31521110
# PERSONALIZATION         1532494782
# PHOTOGRAPHY             4649147655
# PRODUCTIVITY            5793091369
# ...

# %%
df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   13878924415
# COMMUNICATION          11038276251
# TOOLS                   8001771915
# PRODUCTIVITY            5793091369
# SOCIAL                  5487867902
# PHOTOGRAPHY             4649147655
# FAMILY                  4427941505
# VIDEO_PLAYERS           3926902720
# TRAVEL_AND_LOCAL        2894887146
# NEWS_AND_MAGAZINES      2369217760
# ENTERTAINMENT           2113660000
# BOOKS_AND_REFERENCE     1665969576
# PERSONALIZATION         1532494782
# SHOPPING                1400348785
# HEALTH_AND_FITNESS      1144022512
# SPORTS                  1096474498
# BUSINESS                 697164865
# LIFESTYLE                503823539
# MAPS_AND_NAVIGATION      503281890
# FINANCE                  455348734
# WEATHER                  361100520
# EDUCATION                352952000
# FOOD_AND_DRINK           211798751
# DATING                   140926107
# ART_AND_DESIGN           114338100
# HOUSE_AND_HOME            97212461
# ...

# %%
df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).iloc[0]
# Out:
# 13878924415

# %%
df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).head(1)
# Out:
# Category
# GAME    13878924415
# Name: Installs, dtype: int64

# %%
df1=df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False)

# %%
df1.iat[0, 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df1.iat[0, 0]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py:2382, in _ScalarAccessIndexer.__getitem__(self, key)
#    2379         raise ValueError("Invalid call for scalar access (getting)!")
#    2381 key = self._convert_key(key)
# -> 2382 return self.obj._get_value(*key, takeable=self._takeable)
#
# TypeError: _get_value() got multiple values for argument 'takeable'

# %%
df1.max()
# Out:
# 13878924415

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
df['Category'].max()
# Out:
# 'WEATHER'

# %%
df.groupby(['Category'])['Installs'].count().sort_values().groupby(level=0).tail(1)
# Out:
# Category
# BEAUTY                   53
# COMICS                   56
# PARENTING                60
# ART_AND_DESIGN           64
# EVENTS                   64
# HOUSE_AND_HOME           74
# WEATHER                  79
# LIBRARIES_AND_DEMO       84
# AUTO_AND_VEHICLES        85
# ENTERTAINMENT           102
# FOOD_AND_DRINK          112
# EDUCATION               119
# MAPS_AND_NAVIGATION     131
# VIDEO_PLAYERS           163
# DATING                  171
# SHOPPING                202
# TRAVEL_AND_LOCAL        219
# BOOKS_AND_REFERENCE     222
# SOCIAL                  239
# NEWS_AND_MAGAZINES      254
# PHOTOGRAPHY             281
# HEALTH_AND_FITNESS      288
# COMMUNICATION           315
# SPORTS                  325
# FINANCE                 345
# LIFESTYLE               369
# PRODUCTIVITY            374
# PERSONALIZATION         376
# MEDICAL                 395
# BUSINESS                420
# TOOLS                   827
# GAME                    959
# ...

# %%
df.groupby(['Category'])['Installs'].value_counts().to_frame().idxmax()
# Out:
# Installs    (FAMILY, 1000000)
# dtype: object

# %%
df['Category']['Installs'].value_counts().to_frame().idxmax()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:146, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:49, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Installs'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 df['Category']['Installs'].value_counts().to_frame().idxmax()
#
# ...

# %%
df_cat_install=df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()
df_cat_install
# Out:
#                Category     Installs
# 0                  GAME  13878924415
# 1         COMMUNICATION  11038276251
# 2                 TOOLS   8001771915
# 3          PRODUCTIVITY   5793091369
# 4                SOCIAL   5487867902
# 5           PHOTOGRAPHY   4649147655
# 6                FAMILY   4427941505
# 7         VIDEO_PLAYERS   3926902720
# 8      TRAVEL_AND_LOCAL   2894887146
# 9    NEWS_AND_MAGAZINES   2369217760
# 10        ENTERTAINMENT   2113660000
# 11  BOOKS_AND_REFERENCE   1665969576
# 12      PERSONALIZATION   1532494782
# 13             SHOPPING   1400348785
# 14   HEALTH_AND_FITNESS   1144022512
# 15               SPORTS   1096474498
# 16             BUSINESS    697164865
# 17            LIFESTYLE    503823539
# 18  MAPS_AND_NAVIGATION    503281890
# 19              FINANCE    455348734
# 20              WEATHER    361100520
# 21            EDUCATION    352952000
# 22       FOOD_AND_DRINK    211798751
# 23               DATING    140926107
# ...

# %%
df_cat_install.iloc[0]
# Out:
# Category           GAME
# Installs    13878924415
# Name: 0, dtype: object

# %%
df_cat_install.iloc[0]
# Out:
# Category           GAME
# Installs    13878924415
# Name: 0, dtype: object

# %%
df2=df_cat_install.head(10)
df2
# Out:
#              Category     Installs
# 0                GAME  13878924415
# 1       COMMUNICATION  11038276251
# 2               TOOLS   8001771915
# 3        PRODUCTIVITY   5793091369
# 4              SOCIAL   5487867902
# 5         PHOTOGRAPHY   4649147655
# 6              FAMILY   4427941505
# 7       VIDEO_PLAYERS   3926902720
# 8    TRAVEL_AND_LOCAL   2894887146
# 9  NEWS_AND_MAGAZINES   2369217760

# %%
sns.barplot(x='Installs',y='Category', data=df_cat_install.head(10))
# Out:
# <Axes: xlabel='Installs', ylabel='Category'>

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
sns.barplot(x='Installs',y='Category', data=df_cat_install.head(10))
# Out:
# <Axes: xlabel='Installs', ylabel='Category'>

# %%
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %%
dfa=df.groupby(['Category','App'])['Installs'].sum().reset_index()

# %%
dfa
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9654         WEATHER                                      Yahoo Weather
# 9655         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9656         WEATHER                                     Yandex.Weather
# 9657         WEATHER                         weather - weather forecast
# 9658         WEATHER                     wetter.com - Weather and Radar
#
#       Installs
# 0        10000
# 1       100000
# 2         5000
# 3         1000
# 4       100000
# ...

# %%
dfa=dfa.sort_values('Installs',ascending=False)
dfa
# Out:
#                 Category                            App    Installs
# 9311    TRAVEL_AND_LOCAL             Google Street View  1000000000
# 6388  NEWS_AND_MAGAZINES                    Google News  1000000000
# 1145       COMMUNICATION  Skype - free IM & video calls  1000000000
# 9566       VIDEO_PLAYERS                        YouTube  1000000000
# 1181       COMMUNICATION             WhatsApp Messenger  1000000000
# ...                  ...                            ...         ...
# 9275    TRAVEL_AND_LOCAL       EG | Explore Folegandros           0
# 6020             MEDICAL                   EP Cook Book           0
# 3662             FINANCE                    Eu sou Rico           0
# 1797              FAMILY     Ain Arabic Kids Alif Ba ta           0
# 6471  NEWS_AND_MAGAZINES              Sweden Newspapers           0
#
# [9659 rows x 3 columns]

# %%
dfa[dfa.Category=='GAME']
# Out:
#      Category                                                App    Installs
# 4773     GAME                                     Subway Surfers  1000000000
# 4167     GAME                                   Candy Crush Saga   500000000
# 4628     GAME                                                Pou   500000000
# 4802     GAME                                       Temple Run 2   500000000
# 4580     GAME                                     My Talking Tom   500000000
# 4189     GAME                                       Clash Royale   100000000
# 4191     GAME                                     Clash of Clans   100000000
# 4199     GAME                                      Cooking Fever   100000000
# 4219     GAME                                        Crossy Road   100000000
# 4168     GAME                              Candy Crush Soda Saga   100000000
# 4221     GAME                             Cut the Rope FULL FREE   100000000
# ...

# %%
dfa[dfa.Category=='GAME'][:5]
# Out:
#      Category               App    Installs
# 4773     GAME    Subway Surfers  1000000000
# 4167     GAME  Candy Crush Saga   500000000
# 4628     GAME               Pou   500000000
# 4802     GAME      Temple Run 2   500000000
# 4580     GAME    My Talking Tom   500000000

# %%
dfa[dfa.Category=='SOCIAL'][:5]
# Out:
#      Category            App    Installs
# 7883   SOCIAL       Facebook  1000000000
# 7908   SOCIAL        Google+  1000000000
# 7919   SOCIAL      Instagram  1000000000
# 7984   SOCIAL       Snapchat   500000000
# 7885   SOCIAL  Facebook Lite   500000000

# %%
dfa[dfa.Category=='FAMILY'][:5]
# Out:
#      Category                            App   Installs
# 3333   FAMILY               Tom Loves Angela  100000000
# 3290   FAMILY              Talking Tom Cat 2  100000000
# 1976   FAMILY  Bitmoji – Your Personal Emoji  100000000
# 3289   FAMILY                Talking Tom Cat  100000000
# 3287   FAMILY         Talking Tom & Ben News  100000000

# %%
dfa[dfa.Category=='NEWS_AND_MAGAZINES'][:5]
# Out:
#                 Category                                               App  \
# 6388  NEWS_AND_MAGAZINES                                       Google News
# 6381  NEWS_AND_MAGAZINES                      Flipboard: News For Our Time
# 6484  NEWS_AND_MAGAZINES                                           Twitter
# 6357  NEWS_AND_MAGAZINES  Dailyhunt (Newshunt) - Latest News, Viral Videos
# 6502  NEWS_AND_MAGAZINES            detikcom - Latest & Most Complete News
#
#         Installs
# 6388  1000000000
# 6381   500000000
# 6484   500000000
# 6357    50000000
# 6502    10000000

# %%
dfa[dfa.Category=='COMMUNICATION'][:5]
# Out:
#            Category                            App    Installs
# 1145  COMMUNICATION  Skype - free IM & video calls  1000000000
# 1181  COMMUNICATION             WhatsApp Messenger  1000000000
# 1064  COMMUNICATION                       Hangouts  1000000000
# 1058  COMMUNICATION   Google Chrome: Fast & Secure  1000000000
# 1055  COMMUNICATION                          Gmail  1000000000

# %%
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df2 = dfa[dfa.Category == app]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df3,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()

# %%
df.groupby('Type').agg({'Installs': sum})
# Out:
#          Installs
# Type
# Free  75065572646
# Paid     57364881

# %%
df.groupby('Type').agg({'Installs': sum}).plot.pie(y='Installs')
# Out:
# <Axes: ylabel='Installs'>

# %%
df.value_counts('Type')
# Out:
# Type
# Free    8902
# Paid     756
# dtype: int64

# %%
df.value_counts('Type').plot.pie(y='Type')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1,2,figsize=(20,7))
df.value_counts('Type').plot.pie(y='Type',startangle=90, explode=(0.2,0), title='Percentage of the Free App and Paid App', legend=False, autopct='%.2f', ax=ax[0])
ax[0].set(ylabel='Type of Apps')
df.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs', startangle=90, explode=(0.2,0), title='Percentage of Installs Number for Free App and Paid App', legend=False, autopct='%.2f', ax=ax[1])
# Out:
# <Axes: title={'center': 'Percentage of Installs Number for Free App and Paid App'}, ylabel='Installs'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Installs",y="Rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation = 90)
sns.barplot('Category','Size',data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 3
#       1 plt.figure(figsize=(15,15))
#       2 plt.xticks(rotation = 90)
# ----> 3 sns.barplot('Category','Size',data=df)
#       4 plt.show()
#
# TypeError: barplot() got multiple values for argument 'data'

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation = 90)
sns.barplot(x='Category',y='Size',data=df)
plt.show()

# %%
freq=df['year'].value_counts()
freq
# Out:
# 2018    6284
# 2017    1794
# 2016     779
# 2015     449
# 2014     203
# 2013     108
# 2012      26
# 2011      15
# 2010       1
# Name: year, dtype: int64

# %%
freq.plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Rating',data = df,palette="Set1_r")
plt.xticks(rotation =90)
plt.title('Countplot for ratings')             
plt.show()
